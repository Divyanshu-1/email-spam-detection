# %% [markdown]
# ## 1. Importing the dataset

# %%
import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# ## 2. Reading the dataset

# %%
df = pd.read_csv("spam.csv",encoding="latin")  #reading the dataset from excel file using numpy library

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
#renaming the colums for better readibility
df.rename(columns={'v1':'Category','v2':'message'},inplace=True)

# %%
df.head()
# Out:
#   Category                                            message Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# mapping the ham and spam as 0 and 1 by making a new column target
df['target'] = df.Category.map({"ham":0,"spam":1})

# %%
df.head()
# Out:
#   Category                                            message Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4  target
# 0        NaN        NaN       0
# 1        NaN        NaN       0
# 2        NaN        NaN       1
# 3        NaN        NaN       0
# 4        NaN        NaN       0

# %% [markdown]
# ## 3. Converting text data into numerical data

# %%
#importing countvectorizer for convert the data in text to numbers
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()

# %%
# will use X and Y for training and testing
X = df['Message']
y = df['target']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\divya\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File c:\users\divya\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\users\divya\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Message'
#
# ...

# %%
cv = vectorizer.fit(X)
cv_X = cv.transform(X).toarray()

# %% [markdown]
# ## 4. Building Model

# %%
# imporing sklearn for spliting the dataset into testing and training 
from sklearn.model_selection import train_test_split

# %%
# Random State = Controls the shuffling applied to the data before applying the split
# without random_state the X_train data will be changed after each execution
X_train, X_test, y_train, y_test = train_test_split(cv_X, y, test_size = 0.3,random_state=1)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth = 2)
clf.fit(X_train,y_train)

# %%
dt_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 dt_pred = clf.predict(X_test)
#
# NameError: name 'clf' is not defined

# %%
tree.plot_tree(clf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 tree.plot_tree(clf)
#
# NameError: name 'tree' is not defined

# %%
 from sklearn.metrics import accuracy_score
 print("Accuracy Score = ",accuracy_score(y_test, dt_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print("Accuracy Score = ",accuracy_score(y_test, dt_pred))
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ## 5. Predicting

# %%
def Predict(message):
    message = [message]
    message = cv.transform(message).toarray()
    predictedValue = clf.predict(message)
    if(predictedValue == 0):
        print("Ham")
    else:
        print("Spam")

# %%
for i in range(1,1000):
    Predict(df["Message"][i])
# Out:
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Spam
# Ham
# Spam
# Spam
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Spam
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Spam
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Ham
# Spam
# Ham
# Ham
# Ham
# ...

# %%
# Out:
# Ham
