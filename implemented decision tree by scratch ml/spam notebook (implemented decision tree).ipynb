# %% [markdown]
# ## Import the required packages

# %%
import csv
import sklearn
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv('spam.csv', encoding='latin')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# ## Removing unwanted columns

# %%
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
df = df.rename(columns={"v2" : "text", "v1":"label"})

# %%
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Import nltk packages and Punkt Tokenizer Models
# import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\divya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = df.replace(['ham','spam'],[0, 1])

# %%
df.head()
# Out:
#    label                                               text
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Removing all the stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\divya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#remove the punctuations and stopwords
import string
def text_process(text):
    
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = [word for word in text.split() if word.lower() not in stopwords.words('english')]
    
    return " ".join(text)

# %%
df['text'] = df['text'].apply(text_process)

# %%
df.head()
# Out:
#    label                                               text
# 0      0  Go jurong point crazy Available bugis n great ...
# 1      0                            Ok lar Joking wif u oni
# 2      1  Free entry 2 wkly comp win FA Cup final tkts 2...
# 3      0                U dun say early hor U c already say
# 4      0        Nah dont think goes usf lives around though

# %%
text = df['text'].to_numpy()
label = df['label'].to_numpy()

# %% [markdown]
# ## Converting words to vectors using TFIDF Vectorizer

# %%
#convert the text data into vectors
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(df['text'])
vectors.shape
# Out:
# (5572, 9376)

# %%
# features = word_vectors
features = vectors
# fetures = features.toarray()
features
# Out:
# <5572x9376 sparse matrix of type '<class 'numpy.float64'>'
# 	with 47254 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Splitting into training and test set

# %%
#split the dataset into train and test set
X_train, X_test, y_train, y_test = train_test_split(features,label, test_size=0.15, random_state=111)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4736, 9376), (836, 9376), (4736,), (836,))

# %%
# features = pd.Series('features')
X_train = X_train.toarray()

# %%
X_test = X_test.toarray()

# %% [markdown]
# ## Building the model

# %%
#decision tree

import numpy as np
# from Node import Node

class Node:
    def __init__(self, feature=None, threshold=None, left=None, right=None, *, value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value = value
        
    def is_leaf(self):
        return self.value is not None
  
  
class DecisionTree:
    #by default it will make root = NUll and assign max_depth and min_samples_split
    def __init__(self, max_depth=1, min_samples_split=1):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.root = None
        
    # it will check whethr we should stop now or not 
    # here if depth is reach our max or class split is divided into 1 or split samples are less min split
    def searchComplete(self, depth):
        if (depth >= self.max_depth or self.class_labels == 1 or self.n_samples < self.min_samples_split):
            return True
        return False
    
    def entropy(self,y):
        proportions = np.bincount(y) / len(y)
        entropy = -np.sum([p * np.log2(p) for p in proportions if p > 0])
        return entropy
        
	# make the tree split using threshold value
    def createSplit(self, X , thresh):
        left_idx = np.argwhere(X <= thresh).flatten()
        right_idx = np.argwhere(X > thresh).flatten()
        
        # print(left_idx,right_idx)
        return left_idx, right_idx
        
	# implementing the basic information gain formula finding the left subtree and right subtree and subtracting the child loss from its parent loss
    def informationGain(self, X, y, thresh):
        parentLoss = self.entropy(y)
        left_idx, right_idx = self.createSplit(X, thresh)
        n, n_left , n_right = len(y), len(left_idx), len(right_idx)

        if n_left == 0 or n_right == 0:
            return 0
        childLoss = (n_left / n) * self.entropy(y[left_idx]) + (n_right/ n) * self.entropy(y[right_idx])
        return parentLoss - childLoss

	# best function to make the split 
    def bestSplit(self, X, y , features):
        split = {'score' : -1 , 'feat': None, 'thresh': None}
       
        for feat in features:
            X_feat = X[:,feat]
            thresholds = np.unique(X_feat)
            for thresh in thresholds:
                score = self.informationGain(X_feat, y, thresh)
                
                if score > split['score']:
                    split['score'] = score
                    split['feat'] = feat
                    split['thresh'] = thresh
        return split['feat'], split['thresh']

        
    # will have to build tree with given information of depth and training dataset
    def buildTree(self, X, y, depth = 0):

        self.n_samples, self.n_features = X.shape 
        self.class_labels = len(np.unique(y)) 
            
        # check whether we should stop or not
        if self.searchComplete(depth):
            most_common_Label = np.argmax(np.bincount(y))
            return Node(value = most_common_Label)

        # get best split
        rnd_feats = np.random.choice(self.n_features, self.n_features, replace=False) # generates a new random sample from 1D array
        best_feat, best_thresh = self.bestSplit(X, y, rnd_feats) # this function will return best feature and best threshold 
         
        # grow child recursively
        left_idx, right_idx = self.createSplit(X[:, best_feat], best_thresh)
        left_child = self.buildTree(X[left_idx, :], y[left_idx], depth + 1)
        right_child = self.buildTree(X[right_idx, :], y[right_idx], depth + 1)
        return Node(best_feat, best_thresh, left_child, right_child)
        
    def _traverse_tree(self, x, node):
        if node.is_leaf():
            return node.value
        
        if x[node.feature] <= node.threshold:
            return self._traverse_tree(x, node.left)
        return self._traverse_tree(x, node.right)
    
    # will call this function in our jupyter notebook during 
    # building model instead of calling the prebuilt decision tree using sckit learn 
    def fit(self, X, y):
        self.root = self.buildTree(X,y)

    def predict(self, X):
        predictions = [self._traverse_tree(x, self.root) for x in X ]
        return np.array(predictions)

# %%
clf = DecisionTree()

# %%
clf.fit(X_train,y_train)

# %%
dt_pred = clf.predict(X_test)

# %%
def print_metrics(y_test, dt_pred):
    print("Accuracy Score is : ",format(accuracy_score(y_test, dt_pred)))
    print('Precision score is : ' , format(precision_score(y_test, dt_pred)))
    print('Recall score is : ' , format(recall_score(y_test, dt_pred)))
    print('F1 score is : ', format(f1_score(y_test, dt_pred)))
# Out:
# Accuracy Score =  0.8899521531100478
# Precision score =  0.620253164556962
# Recall score =  0.44144144144144143

# %%
print_metrics(y_test, dt_pred)

# %% [markdown]
# # Predicting

# %%
def Predict(message):
    message = [message]
    message = vectorizer.transform(message).toarray()
    predictedValue = clf.predict(message)
    if(predictedValue == 0):
        print("Ham")
    else:
        print("Spam")

# %%
for i in range(1,1000):
    print(df["text"][i],":", end = " ")
    Predict(df["text"][i])
# Out:
# Ok lar Joking wif u oni : Ham
# Free entry 2 wkly comp win FA Cup final tkts 21st May 2005 Text FA 87121 receive entry questionstd txt rateTCs apply 08452810075over18s : Ham
# U dun say early hor U c already say : Ham
# Nah dont think goes usf lives around though : Ham
# FreeMsg Hey darling 3 weeks word back Id like fun still Tb ok XxX std chgs send å£150 rcv : Ham
# Even brother like speak treat like aids patent : Ham
# per request Melle Melle Oru Minnaminunginte Nurungu Vettam set callertune Callers Press 9 copy friends Callertune : Ham
# WINNER valued network customer selected receivea å£900 prize reward claim call 09061701461 Claim code KL341 Valid 12 hours : Spam
# mobile 11 months U R entitled Update latest colour mobiles camera Free Call Mobile Update Co FREE 08002986030 : Spam
# Im gonna home soon dont want talk stuff anymore tonight k Ive cried enough today : Ham
# SIX chances win CASH 100 20000 pounds txt CSH11 send 87575 Cost 150pday 6days 16 TsandCs apply Reply HL 4 info : Ham
# URGENT 1 week FREE membership å£100000 Prize Jackpot Txt word CLAIM 81010 TC wwwdbuknet LCCLTD POBOX 4403LDNW1A7RW18 : Ham
# Ive searching right words thank breather promise wont take help granted fulfil promise wonderful blessing times : Ham
# DATE SUNDAY : Ham
# XXXMobileMovieClub use credit click WAP link next txt message click httpwap xxxmobilemovieclubcomnQJKGIGHJJGCBL : Ham
# Oh kim watching : Ham
# Eh u remember 2 spell name Yes v naughty make v wet : Ham
# Fine thatåÕs way u feel ThatåÕs way gota b : Ham
# England v Macedonia dont miss goalsteam news Txt ur national team 87077 eg ENGLAND 87077 TryWALES SCOTLAND 4txtÌ¼120 POBOXox36504W45WQ 16 : Ham
# seriously spell name : Ham
# IÛ÷m going try 2 months ha ha joking : Ham
# Ì pay first lar da stock comin : Ham
# Aft finish lunch go str lor Ard 3 smth lor U finish ur lunch already : Ham
# Ffffffffff Alright way meet sooner : Ham
# forced eat slice Im really hungry tho sucks Mark getting worried knows Im sick turn pizza Lol : Ham
# Lol always convincing : Ham
# catch bus frying egg make tea eating moms left dinner feel Love : Ham
# Im back amp packing car Ill let know theres room : Ham
# Ahhh Work vaguely remember feel like Lol : Ham
# Wait thats still clear sure sarcastic thats x doesnt want live us : Ham
# Yeah got 2 v apologetic n fallen actin like spoilt child got caught Till 2 wont go badly cheers : Ham
# K tell anything : Ham
# fear fainting housework Quick cuppa : Ham
# Thanks subscription Ringtone UK mobile charged å£5month Please confirm replying YES reply charged : Ham
# Yup Ok go home look timings msg Ì Xuhui going learn 2nd may lesson 8am : Ham
# Oops Ill let know roommates done : Ham
# see letter B car : Ham
# Anything lor U decide : Ham
# Hello Hows saturday go texting see youd decided anything tomo im trying invite anything : Ham
# Pls go ahead watts wanted sure great weekend Abiola : Ham
# forget tell want need crave love sweet Arabian steed Mmmmmm Yummy : Ham
# 07732584351 Rodger Burns MSG tried call reply sms free nokia mobile free camcorder Please call 08000930705 delivery tomorrow : Spam
# SEEING : Ham
# Great hope like man well endowed ltgt inches : Ham
# callsmessagesmissed calls : Ham
# Didnt get hep b immunisation nigeria : Ham
# Fair enough anything going : Ham
# Yeah hopefully tyler cant could maybe ask around bit : Ham
# U dont know stubborn didnt even want go hospital kept telling Mark Im weak sucker Hospitals weak suckers : Ham
# thinked First time saw class : Ham
# gram usually runs like ltgt half eighth smarter though gets almost whole second gram ltgt : Ham
# K fyi x ride early tomorrow morning hes crashing place tonight : Ham
# Wow never realized embarassed accomodations thought liked since best could always seemed happy cave Im sorry didnt dont give Im sorry offered Im sorry room embarassing : Ham
# SMS ac Sptv New Jersey Devils Detroit Red Wings play Ice Hockey Correct Incorrect End Reply END SPTV : Ham
# know Mallika Sherawat yesterday Find ltURLgt : Ham
# Congrats 1 year special cinema pass 2 call 09061209465 C Suprman V Matrix3 StarWars3 etc 4 FREE bx420ip45we 150pm Dont miss : Spam
# Sorry Ill call later meeting : Spam
# Tell reached : Ham
# Yesgauti sehwag odi series : Ham
# gonna pick 1 burger way home cant even move Pain killing : Ham
# Ha ha ha good joke Girls situation seekers : Ham
# part checking IQ : Ham
# Sorry roommates took forever ok come : Ham
# Ok lar double check wif da hair dresser already said wun cut v short said cut look nice : Ham
# valued customer pleased advise following recent review Mob awarded å£1500 Bonus Prize call 09066364589 : Spam
# Today song dedicated day song u dedicate Send ur valuable frnds first rply : Ham
# Urgent UR awarded complimentary trip EuroDisinc Trav AcoEntry41 å£1000 claim txt DIS 87121 186å£150moreFrmMob ShrAcomOrSglSuplt10 LS1 3AJ : Ham
# hear new Divorce Barbie comes Kens stuff : Ham
# plane give month end : Ham
# Wah lucky man save money Hee : Ham
# Finished class : Ham
# HI BABE IM HOME WANNA SOMETHING XX : Ham
# Kkwhere youhow performed : Ham
# U call : Spam
# waiting machan Call free : Spam
# Thats cool gentleman treat dignity respect : Ham
# like peoples much shy pa : Ham
# operate ltgt : Ham
# Still looking job much Tas earn : Ham
# Sorry Ill call later : Spam
# K call ah : Spam
# Ok way home hi hi : Ham
# place man : Ham
# Yup next stop : Ham
# call later dont network urgnt sms : Spam
# real u getting yo need 2 tickets one jacket Im done already used multis : Ham
# Yes started send requests make pain came back Im back bed Double coins factory gotta cash nitros : Ham
# Im really still tonight babe : Ham
# Ela kanoil download come wen ur free : Ham
# Yeah DonÛ÷t stand close tho youÛ÷ll catch something : Ham
# Sorry pain ok meet another night spent late afternoon casualty means havent done stuff42moro includes time sheets Sorry : Ham
# Smile Pleasure Smile Pain Smile trouble pours like Rain Smile sum1 Hurts U Smile becoz SOMEONE still Loves see u Smiling : Ham
# Please call customer service representative 0800 169 6031 10am9pm guaranteed å£1000 cash å£5000 prize : Spam
# Havent planning buy later check already lido got 530 show e afternoon U finish work already : Ham
# free ringtone waiting collected Simply text password MIX 85069 verify Get Usher Britney FML : Ham
# Watching telugu moviewat abt u : Ham
# see finish loads loans pay : Ham
# Hi Wk ok hols Yes bit run Forgot hairdressers appointment four need get home n shower beforehand cause prob u ham : Ham
# Please dont text anymore nothing else say : Ham
# Okay name ur price long legal Wen pick u ave x ams xx : Ham
# Im still looking car buy gone 4the driving test yet : Ham
# per request Melle Melle Oru Minnaminunginte Nurungu Vettam set callertune Callers Press 9 copy friends Callertune : Ham
# wow Youre right didnt mean guess gave boston men changed search location nyc something changed Cuz signin page still says boston : Ham
# Umma life vava umma love lot dear : Ham
# Thanks lot wishes birthday Thanks making birthday truly memorable : Ham
# Aight Ill hit get cash : Ham
# would ip address test considering computer isnt minecraft server : Ham
# know Grumpy old people mom like better lying always one play jokes : Ham
# Dont worry guess hes busy : Ham
# plural noun research : Ham
# Going dinnermsg : Ham
# Im ok wif cos like 2 try new things scared u dun like mah Cos u said loud : Ham
# GENT trying contact Last weekends draw shows å£1000 prize GUARANTEED Call 09064012160 Claim Code K52 Valid 12hrs 150ppm : Spam
# Wa ur openin sentence formal Anyway im fine juz tt im eatin much n puttin weightHaha anythin special happened : Ham
# entered cabin PA said Happy Bday Boss felt special askd 4 lunch lunch invited apartment went : Ham
# winner U specially selected 2 receive å£1000 4 holiday flights inc speak live operator 2 claim 0871277810910pmin 18 : Ham
# Goodo Yes must speak friday eggpotato ratio tortilla needed : Ham
# Hmmmy uncle informed hes paying school directly pls buy food : Ham
# PRIVATE 2004 Account Statement 07742676969 shows 786 unredeemed Bonus Points claim call 08719180248 Identifier Code 45239 Expires : Spam
# URGENT Mobile awarded å£2000 Bonus Caller Prize 5903 final try contact U Call Landline 09064019788 BOX42WR29C 150PPM : Spam
# new address applespairsall malarky : Ham
# Todays Voda numbers ending 7548 selected receive 350 award match please call 08712300220 quoting claim code 4041 standard rates app : Spam
# going sao mu today done 12 : Ham
# ÌÏ predict wat time Ìll finish buying : Ham
# Good stuff : Ham
# knowyetunde hasnt sent money yet sent text bother sending dont involve anything shouldnt imposed anything first place apologise : Ham
# room : Ham
# HEY GIRL R U HOPE U R WELL DEL R BAK LONG TIME C GIVE CALL SUM TIME LUCYxx : Spam
# Kkhow much cost : Ham
# Im home : Ham
# Dear call Tmorrowpls accomodate : Spam
# First answer question : Ham
# Sunshine Quiz Wkly Q Win top Sony DVD player u know country Algarve Txt ansr 82277 å£150 SPTyrone : Ham
# Want 2 get laid tonight Want real Dogging locations sent direct 2 ur mob Join UKs largest Dogging Network bt Txting GRAVEL 69888 Nt ec2a 31pmsg150p : Ham
# haf msn yijuehotmailcom : Ham
# call meet : Spam
# check rooms befor activities : Ham
# Youll rcv msgs chat svc FREE Hardcore services text GO 69988 u get nothing u must Age Verify yr network try : Ham
# Got c lazy type forgot Ì lect saw pouch like v nice : Ham
# K text youre way : Ham
# Sir Waiting mail : Ham
# swt thought Nver get tired little things 4 lovable persons Cozsomtimes little things occupy biggest part Hearts Gud ni8 : Ham
# know pls open back : Ham
# Yes see ya dot : Ham
# Whats staff name taking class us : Ham
# FreeMsg havent replied text Im Randy sexy female live local Luv hear u Netcollex Ltd 08700621170150p per msg reply Stop end : Ham
# Ummmawill call check inour life begin qatar pls pray hard : Spam
# Ki deleted contact : Ham
# Sindu got job birla soft : Ham
# wine flowing im nevering : Ham
# Yup thk cine better cos need 2 go 2 plaza mah : Ham
# Ok Ur typical reply : Ham
# per request Melle Melle Oru Minnaminunginte Nurungu Vettam set callertune Callers Press 9 copy friends Callertune : Ham
# everywhere dirt floor windows even shirt sometimes open mouth comes flowing dream world without half chores time joy lots tv shows ill see guess like things must exist like rain hail mist time done become one : Ham
# Aaooooright work : Ham
# Im leaving house : Ham
# Hello love get interview today happy good boy think meAre missing : Ham
# Customer service annoncement New Years delivery waiting Please call 07046744435 arrange delivery : Spam
# winner U specially selected 2 receive å£1000 cash 4 holiday flights inc speak live operator 2 claim 0871277810810 : Ham
# Keep safe need miss already envy everyone sees real life : Ham
# New car house parentsi new job hand : Ham
# Im love Im excited day spend make happy : Ham
# PLS STOP bootydelious 32F inviting friend Reply YES434 NO434 See wwwSMSacubootydelious STOP Send STOP FRND 62468 : Ham
# BangBabes Ur order way U receive Service Msg 2 download UR content U GoTo wap bangb tv UR mobile internetservice menu : Ham
# place ur points e cultures module already : Ham
# URGENT trying contact Last weekends draw shows å£900 prize GUARANTEED Call 09061701939 Claim code S89 Valid 12hrs : Spam
# Hi frnd best way avoid missunderstding wit beloved ones : Ham
# Great escape fancy bridge needs lager See tomo : Ham
# Yes completely formclark also utter waste : Ham
# Sir need AXIS BANK account bank address : Ham
# Hmmm Thk sure got time hop ard Ya go 4 free abt Muz call u discuss liao : Spam
# time coming later : Ham
# Bloody hell cant believe forgot surname Mr Ill give u clue spanish begins : Ham
ar lor wait 4 mum 2 finish sch lunch lor whole morning stay home clean room room quite clean Hee : Ham
# know lab goggles went : Ham
# open door : Ham
# Waiting call : Spam
# Nope waiting sch 4 daddy : Ham
# 1000 cash 2000 prize claim call09050000327 : Ham
# Im tired arguing week week want ill : Ham
# ÌÏ wait 4 sch finish ard 5 : Ham
# mobile number å£5000 claim calls us back ring claims hot line 09050005321 : Ham
# Arngd marriage u r walkin unfortuntly snake bites u bt love marriage dancing frnt snake amp sayin Bite bite : Ham
# Huh early Ì dinner outside izzit : Ham
# Ok anyway need change said : Ham
# tried contact reply offer 750 mins 150 textand new video phone call 08002988890 reply free delivery tomorrow : Spam
# exwife able kids want kids one day : Ham
# hows scotland Hope showing JJC tendencies Take care Live dream : Ham
# Tell u headache want use 1 hour sick time : Ham
# dun thk ill quit yet Hmmm go jazz Yogasana oso go meet em lessons den : Ham
# Pete please ring meive hardly gotany credit : Ham
# Ya srsly better yi tho : Ham
# Im meeting call later : Spam
# ur chance win å£250 wkly shopping spree TXT SHOP 80878 TsCs wwwtxt2shopcom custcare 08715705022 1x150pwk : Ham
# specially selected receive 2000 pound award Call 08712402050 lines close Cost 10ppm 16 TCs apply AG Promo : Spam
# PRIVATE 2003 Account Statement 07753741225 shows 800 unredeemed points Call 08715203677 Identifier Code 42478 Expires 241004 : Spam
# still grand prix : Ham
# met stranger choose friend long world stands friendship never ends Lets Friends forever Gud nitz : Ham
# great : Ham
# Gud mrng dear nice day : Ham
# important customer service announcement Call FREEPHONE 0800 542 0825 : Spam
# exhausted train morning much wine pie sleep well : Ham
# Im going buy mums present ar : Ham
# Mind blastin Tsunamis occur Rajnikant stopped swimming Indian OceanD : Ham
# u sending home first ok lor Im ready yet : Ham
# Speaking cash yet : Ham
# happy come noon : Ham
# Meet lunch la : Ham
# TaKe CaRE n gET WeLL sOOn : Ham
# XCLUSIVECLUBSAISAI 2MOROW 285 SOIREE SPECIALE ZOUK NICHOLS PARISFREE ROSES 2 LADIES info 0794674629107880867867 : Ham
# meant say cant wait see u getting bored bridgwater banter : Ham
# Neva mind ok : Ham
# fine imma get drink somethin Want come find : Ham
# 22 days kick Euro2004 U kept date latest news results daily removed send GET TXT STOP 83222 : Ham
# valentine game Send dis msg ur friends 5 answers r someone really loves u Ques colour suits bestrply : Ham
# many dependents : Ham
# THANX4 TODAY CER NICE 2 CATCH AVE 2 FIND TIME OFTEN OH WELL TAKE CARE C U SOONC : Ham
# called said himthen choose future : Ham
# Happy valentines day know early hundreds handsomes beauties wish thought finish aunties uncles 1st : Ham
# like v shock leh Cos telling shuhui like telling leona also Like dat almost know liao got ask abt ur reaction lor : Ham
# family happiness : Ham
# come n pick Ì Come immediately aft ur lesson : Ham
# Let snow Let snow kind weather brings ppl together friendships grow : Ham
# Dear got ltgt dollars hi hi : Ham
# Good words words may leave u dismay many times : Ham
# MAKE SURE ALEX KNOWS BIRTHDAY FIFTEEN MINUTES FAR YOURE CONCERNED : Ham
# sorry got things may pub later : Ham
# Nah straight bring bud drinks something thats actually little useful straight cash : Ham
# Haha good hear Im officially paid market 8th : Ham
# many licks take get center tootsie pop : Ham
# Yup thk r e teacher said make face look longer Darren ask 2 cut short : Ham
ochin pls call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engaged ans holiday : Spam
# Thanks love torch bold : Ham
# Forwarded 448712404000Please CALL 08712404000 immediately urgent message waiting : Spam
# farm open : Ham
# Sorry trouble u buy 4d dad 1405 1680 1843 2 big 1 small sat n sun Thanx : Ham
# sister law hope great month saying hey Abiola : Ham
# purchase stuff today mail po box number : Ham
# Ah poop Looks like ill prob send laptop get fixed cuz gpu problem : Ham
# Good Good job like entrepreneurs : Ham
# Aight close still around alexs place : Ham
# meet corporation st outside gap Û see mind working : Ham
# Mum ask Ì buy food home : Ham
# Ku also dont msg reply msg : Ham
# much r Ì willing pay : Ham
# Sorry Ill call later : Spam
# important prevent dehydration giving enough fluids : Ham
# Thats bit weird even supposed happening good idea sure pub : Ham
# True deari sat pray evening felt soso smsd time : Ham
# dont think get away trek long family town sorry : Ham
# wanna gym harri : Ham
# Quite late lar Ard 12 anyway wun b drivin : Ham
# review KEEP fantastic Nokia NGage game deck Club Nokia go 2 wwwcnupdatescomnewsletter unsubscribe alerts reply word : Ham
# 4mths half price Orange line rental latest camera phones 4 FREE phone 11mths Call MobilesDirect free 08000938767 update or2stoptxt TCs : Spam
# Height Confidence Aeronautics professors wer calld amp wer askd 2 sit aeroplane Aftr sat wer told dat plane ws made students Dey hurried plane Bt 1 didnt move saidif made students : Ham
# seems like weird timing night g want come smoke day shitstorm attributed always coming making everyone smoke : Ham
# 08714712388 10am7pm Cost 10p : Ham
# Save stress person dorm account send account details money sent : Ham
# also knows lunch menu da know : Ham
# stuff sell ill tell : Ham
# 449071512431 URGENT 2nd attempt contact UU å£1250 CALL 09071512433 b4 050703 TCsBCM4235WC1N3XX callcost 150ppm mobilesvary maxå£7 50 : Spam
# Book lesson msg call work sth Im going get specs membership PX3748 : Spam
# guaranteed å£1000 cash å£2000 prize claim yr prize call customer service representative 08714712394 10am7pm : Spam
# Macha dont feel upseti assume mindsetbelieve one evening wonderful plans usLET LIFE BEGIN AGAINcall anytime : Ham
# Oh Send address : Ham
# Sfine Anytime best : Ham
# wondar full flim : Ham
# Ya even cookies jelly : Ham
# world running stillmaybe feeling sameso itor admiti madthen correctionor let call lifeand keep running worldmay u r also runninglets run : Spam
# Got looks scrumptious daddy wants eat night long : Ham
# cos lar im ba dao ok 1 pm lor u never ask go ah said u would ask fri said u ask today : Ham
# Alright omw gotta change order half8th : Ham
# Exactly Anyways far jide study visiting : Ham
# Dunno u ask : Ham
# Email AlertFrom Jeri StewartSize 2KBSubject Lowcost prescripiton drvgsTo listen email call 123 : Spam
# didnt Spring coming early yay : Ham
# Lol wont feel bad use money take steak dinner : Ham
# Even u dont get trouble convincingjust tel twice tel neglect msgs dont c read itjust dont reply : Ham
# Leaving qatar tonite search opportunityall went fastpls add ur prayers dearRakhesh : Ham
# one talking : Ham
# Thanks looking really appreciate : Ham
# Hi Customer Loyalty OfferThe NEW Nokia6650 Mobile å£10 TXTAUCTION Txt word START 81151 get 4TCtxt TC 150pMTmsg : Ham
# Wish : Ham
# Haha mayb ure rite U know well Da feeling liked someone gd lor U faster go find one gals group attached liao : Ham
# Yes Glad made : Ham
# well little time Thing good times ahead : Ham
orange customer may claim FREE CAMERA PHONE upgrade loyalty Call 0207 153 9996 Offer ends 14thMarch TCs apply Optout availa : Spam
# Petey boy whereare friendsare theKingshead come canlove Nic : Ham
# Ok msg u b4 leave house : Ham
# Gimme ltgt minutes ago : Ham
# Last Chance Claim ur å£150 worth discount vouchers today Text SHOP 85023 SavaMob offers mobile Cs SavaMob POBOX84 M263UZ å£300 Sub 16 : Ham
# Appt ltTIMEgt fault u dont listen told u twice : Ham
# FREE 1st week No1 Nokia tone 4 ur mobile every week txt NOKIA 8077 Get txting tell ur mates wwwgetzedcouk POBox 36504 W45WQ 16 norm150ptone : Ham
# guaranteed å£200 award even å£1000 cashto claim UR award call free 08000407165 18 2 stop getstop 88222 PHP RG21 4JX : Spam
# K Ill 4 : Ham
# dled 3d imp : Ham
# sure make sure knows aint smokin yet : Ham
# Boooo always work quit : Ham
# taking half day leave bec well : Ham
# Ugh dont wanna get bed warm : Ham
# Ssnervous ltgt : Ham
# theres ring comes guys costumes gift future yowifes Hint hint : Ham
# Congratulations ur awarded either å£500 CD gift vouchers Free entry 2 å£100 weekly draw txt MUSIC 87066 TnCs wwwLdewcom1win150ppmx3age16 : Ham
# borrow ur bag ok : Ham
# U outbid simonwatson5120 Shinco DVD Plyr 2 bid visit sms acsmsrewards 2 end bid notifications reply END : Ham
# Wheres boytoy miss happened : Ham
# lots used ones babe model doesnt help Youi bring hell match : Ham
# Also bringing galileo dobby : Ham
# responding : Ham
# BOO BABE U ENJOYIN YOURJOB U SEEMED 2 B GETTIN WELL HUNNYHOPE URE OKTAKE CARE IåÕLLSPEAK 2U SOONLOTS LOVEME XXXX : Ham
# Good afternoon starshine Hows boytoy crave yet Ache fuck sips cappuccino miss babe teasing kiss : Ham
# road cant txt : Ham
# SMSSERVICES yourinclusive text credits pls goto wwwcomuknet login 3qxj9 unsubscribe STOP extra charge help 08702840625COMUK 220CM2 9AE : Ham
# 25p 4 alfie Moons Children need song ur mob Tell ur m8s Txt Tone charity 8007 Nokias Poly charity polys zed 08701417012 profit 2 charity : Ham
# good evening Ttyl : Ham
# Hmm Bits pieces lol sighs : Ham
# Hahahause brain dear : Ham
# Hey got mail : Ham
# Sorry light turned green meant another friend wanted ltgt worth may around : Ham
# Thanks yesterday sir wonderful Hope enjoyed burial MojiBiola : Ham
# U secret admirer REVEAL thinks U R special Call 09065174042 opt Reply REVEAL STOP 150 per msg recd Cust care 07821230901 : Spam
# Hi mate RV u hav nice hol message 3 say hello coz havenåÕt sent u 1 ages started driving stay roadsRVx : Ham
# Dear Voucher Holder claim weeks offer PC please go httpwwwetlpcoukexpressoffer TsCs apply stop texts txt STOP 80062 : Ham
# Thank much skyped wit kz sura didnt get pleasure company Hope good Weve given ultimatum oh countin aburo Enjoy message sent days ago : Ham
# Surely result offer : Ham
# Good Morning Dear great amp successful day : Ham
# want 750 anytime network mins 150 text NEW VIDEO phone five pounds per week call 08002888812 reply delivery tomorrow : Spam
# Sir late paying rent past months pay ltgt charge felt would inconsiderate nag something give great cost thats didnt speak however recession wont able pay charge month hence askin well ahead months end please help Thanks : Ham
# tried contact offer New Video Phone 750 anytime network mins HALF PRICE Rental camcorder call 08000930705 reply delivery Wed : Spam
# Last chance 2 claim ur å£150 worth discount vouchersText YES 85023 nowSavaMobmember offers mobile Cs 08717898035 å£300 Sub 16 Remove txt X STOP : Ham
# luv u soo much u donåÕt understand special u r 2 ring u 2morrow luv u xxx : Ham
# Pls send comprehensive mail im paying much : Ham
# Prashanthettans mother passed away last night pray family : Ham
# Urgent call 09066350750 landline complimentary 4 Ibiza Holiday 10000 cash await collection SAE TCs PO BOX 434 SK3 8WP 150 ppm 18 : Spam
# Kkwhen going : Ham
# Meanwhile shit suite xavier decided give us ltgt seconds warning samantha coming playing jays guitar impress shit Also dont think doug realizes dont live anymore : Ham
# stomach thru much trauma swear cant eat better lose weight : Ham
# officewhats mattermsg nowi call break : Spam
# Yeah theres barely enough room two us x many fucking shoes Sorry man see later : Ham
# Todays Offer Claim ur å£150 worth discount vouchers Text YES 85023 SavaMob member offers mobile Cs 08717898035 å£300 Sub 16 Unsub reply X : Ham
# U reach orchard already U wan 2 go buy tickets first : Ham
# real baby want bring inner tigress : Ham
# da run activate full version da : Ham
# AH POOR BABYHOPE URFEELING BETTERSN LUV PROBTHAT OVERDOSE WORK HEY GO CAREFUL SPK 2 U SN LOTS LOVEJEN XXX : Ham
# Stop story Ive told ive returned hes saying order : Ham
# Talk sexy Make new friends fall love worlds discreet text dating service text VIP 83110 see could meet : Ham
# Going take babe : Ham
# Hai ana tomarrow coming morning ltDECIMALgt ill sathy go RTO office Reply came home : Ham
# Spoons okay : Ham
# say somebody named tampa : Ham
# work Going min : Ham
# brother genius : Ham
# Sorry guess whenever get hold connections maybe hour two Ill text : Ham
# u find time bus coz need sort stuff : Ham
# Dude ive seeing lotta corvettes lately : Ham
# Congratulations ur awarded either yrs supply CDs Virgin Records Mystery Gift GUARANTEED Call 09061104283 TsCs wwwsmsconet å£150pm approx 3mins : Spam
# consider walls bunkers shit important never play peaceful guess place high enough dont matter : Ham
# PRIVATE 2003 Account Statement 07808 XXXXXX shows 800 unredeemed points Call 08719899217 Identifier Code 41685 Expires 071104 : Spam
# Hello need posh birds chaps user trial prods champneys put need address dob asap Ta r : Ham
# U want Xmas 100 free text messages new video phone half price line rental Call free 0800 0721072 find : Spam
# Well officially philosophical hole u wanna call home ready saved : Spam
# going goodno problembut still need little experience understand american customer voice : Ham
# Ill text drop x : Ham
# Ugh long day Im exhausted want cuddle take nap : Ham
# Talk Atleast Day Otherwise Miss Best FRIEND WORLD Shakespeare SHESIL ltgt : Ham
# Shop till u Drop either 10K 5K å£500 Cash å£100 Travel voucher Call 09064011000 NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary : Spam
# castor need see something : Ham
# Sunshine Quiz Wkly Q Win top Sony DVD player u know country Liverpool played mid week Txt ansr 82277 å£150 SPTyrone : Ham
# U secret admirer looking 2 make contact Ufind Rreveal thinks UR specialcall 09058094565 : Ham
# U Secret Admirer looking 2 make contact Ufind Rreveal thinks UR specialcall 09065171142stopsms08 : Ham
# Reminder downloaded content already paid Goto httpdoit mymoby tv collect content : Ham
# see knew giving break times woul lead always wanting miss curfew gonna gibe til one MIDNIGHT movie gonna get til 2 need come home need getsleep anything need b studdying ear training : Ham
# love give massages use lots baby oil fave position : Ham
# Dude go sup : Ham
# Yoyyooo u know change permissions drive mac usb flash drive : Ham
# Gibbs unsoldmike hussey : Ham
# like talk pa able dont know : Ham
# dun cut short leh U dun like ah failed Shes quite sad : Ham
# unbelievable faglord : Ham
# Wifehow knew time murder exactly : Ham
# ask princess : Ham
# great princess thinking : Ham
# Nutter Cutter Ctter Cttergg Cttargg Ctargg Ctagg ie : Ham
# ok noe ure busy im really bored msg u oso dunno wat colour choose 4 one : Ham
# Doesnt g class early tomorrow thus shouldnt trying smoke ltgt : Ham
# Superb Thought grateful u dont everything u want means u still opportunity happier tomorrow u today : Ham
# Hope good week checking : Ham
# Im used hope agents dont drop since ive booked things year whole boston nyc experiment : Ham
# Thursday night Yeah sure thing well work : Ham
# free ringtone waiting collected Simply text password MIX 85069 verify Get Usher Britney FML : Ham
# Probably money worries Things coming due several outstanding invoices work two three months ago : Ham
# possible teach : Ham
# wonder phone battery went dead tell love babe : Ham
# Lovely smell bus aint tobacco : Ham
# getting worried derek taylor already assumed worst : Ham
# Hey whats charles sorry late reply : Ham
# lastest Stereophonics Marley Dizzee Racal Libertines Strokes Win Nookii games Flirt Click TheMob WAP Bookmark text WAP 82468 : Ham
# Ill give Plus said grinule greet whenever speak : Ham
# WHITE FUDGE OREOS STORES : Ham
# January Male Sale Hot Gay chat cheaper call 08709222922 National rate 15pmin cheap 78pmin peak stop texts call 08712460324 10pmin : Spam
# love come took long leave Zahers got words ym happy see sad left miss : Ham
# sorry hurt : Ham
# Cant feel nauseous Im pissed didnt eat sweets week cause today planning pig dieting week Im hungry : Ham
# Ok lor early still project meeting : Ham
# Call da waiting call : Spam
# could ask carlos could get anybody else chip : Ham
# actually send reminder today wonderful weekend : Ham
# people see msgs think Iam addicted msging wrong Bcoz dont know Iam addicted sweet Friends BSLVYL : Ham
# Hey gave photo registered driving ah Tmr wanna meet yck : Ham
# Dont talk ever ok word : Ham
# u wana see : Ham
# way school pls send ashleys number : Ham
# shall fine avalarr hollalater : Ham
# went attend another two rounds todaybut still didt reach home : Ham
# Actually deleted old websitenow blogging magicalsongsblogspotcom : Ham
# K wait chikkuil send aftr ltgt mins : Ham
# Im diet ate 1 many slices pizza yesterday Ugh Im ALWAYS diet : Ham
# Ki give kvb acc details : Ham
# Oh come ah : Ham
# money r lucky winner 2 claim prize text money 2 88600 å£1million give away ppt150x3normal text rate box403 w1t1jy : Ham
# Im really sorry wont b able 2 fridayhope u find alternativehope yr terms going ok : Ham
# Congratulations ore mo owo wa Enjoy wish many happy moments fro wherever go : Ham
# samus shoulders yet : Ham
# time think youll Need know near campus : Ham
# Dear Matthew please call 09063440451 landline complimentary 4Lux Tenerife holiday å£1000 CASH await collection ppm150 SAE TCs Box334 SK38XH : Spam
# dun wear jeans lor : Ham
# Since side fever vomitin : Ham
# Kkare college : Ham
# Urgent call 09061749602 Landline complimentary 4 Tenerife Holiday å£10000 cash await collection SAE TCs BOX 528 HP20 1YF 150ppm 18 : Spam
# Better Made Friday stuffed like pig yesterday feel bleh least writhing pain kind bleh : Ham
# sell well tons coins sell coins someone thru paypal Voila Money back life pockets : Ham
# Theyre lots places hospitals medical places safe : Ham
# getting touch folks waiting company txt back NAME AGE opt Enjoy community 150pSMS : Ham
# also Ive sorta blown couple times recently id rather text blue looking weed : Ham
# sent scores sophas secondary application schools think thinking applying research cost also Contact joke ogunrinde school one less expensive ones : Ham
# cant wait see photos useful : Ham
# Ur cashbalance currently 500 pounds maximize ur cashin send GO 86688 150pmsg CC 08718720201 PO BOX 11414 TCRW1 : Ham
# Hey booked kb sat already lessons going ah Keep sat night free need meet confirm lodging : Ham
# Chk ur belovd ms dict : Ham
# time want come : Ham
# Awesome lemme know whenever youre around : Ham
# Shb b ok lor Thanx : Ham
# Beautiful Truth Gravity Read carefully heart feels light someone feels heavy someone leaves GOOD NIGHT : Ham
# Also remember get dobbys bowl car : Ham
# Filthy stories GIRLS waiting : Ham
# Sorry c ur msg Yar lor poor thing 4 one night Tmr ull brand new room 2 sleep : Ham
# Love isnt decision feeling could decide love life would much simpler less magical : Ham
# Welp apparently retired : Ham
# sort code acc bank natwest reply confirm ive sent right person : Ham
#  : Ham
# U sure u cant take sick time : Ham
# URGENT trying contact U Todays draw shows å£800 prize GUARANTEED Call 09050001808 land line Claim M95 Valid12hrs : Spam
# Watching cartoon listening music amp eve go temple amp church u : Ham
# Yo chad gymnastics class wanna take site says Christians class full : Ham
# much buzy : Ham
# better still catch let ask sell ltgt : Ham
# sure night menu know noon menu : Ham
# u want come backa beautiful necklace token heart youthats give WIFE LIKINGBE SEENO ONE give thatdont call mei wait till come : Spam
# willing go aptitude class : Ham
# wont b 215 trying 2 sort house ok : Ham
# Yar lor wan 2 go c horse racing today mah eat earlier lor ate chicken rice U : Ham
# Haha awesome omw back : Ham
# Yup thk e shop closes lor : Ham
# account number : Ham
# Eh u send wrongly lar : Ham
# Hey ad crap nite borin without ya 2 boggy u boring biatch Thanx u wait til nxt time il ave ya : Ham
# Ok shall talk : Ham
# Dont hesitate know second time weakness like keep notebook eat day anything changed day sure nothing : Ham
# Hey pay salary de ltgt : Ham
# Another month need chocolate weed alcohol : Ham
# started searching get job dayshe great potential talent : Ham
# Reckon need town eightish walk carpark : Ham
# Congrats 2 mobile 3G Videophones R call 09063458130 videochat wid mates play java games Dload polyPH music noline rentl : Spam
# LOOK FUCKIN TIME FUCK THINK : Ham
# Yo guess dropped : Ham
# Carlos says hell mu ltgt minutes : Ham
# Im office call ltgt min : Spam
# Geeee miss already know think Fuck cant wait till next year together loving kiss : Ham
# Yun ahthe ubi one say Ì wan call tomorrowcall 67441233 look ireneere got bus822656166382 Ubi cresubi tech park6ph 1st 5wkg daysÌ¬n : Spam
# Ugh Gotta drive back sd la butt sore : Ham
# 26th JULY : Ham
# Hi im relaxing time ever get 7am every day party good night get home tomorrow 5ish : Ham
# Ì ÌÏ wan come come lor din c stripes skirt : Ham
# Xmas story peace Xmas msg love Xmas miracle jesus Hav blessed month ahead amp wish U Merry Xmas : Ham
# cant dont number : Ham
# Change e one next escalator : Ham
# Yetunde im class run water make ok Pls : Ham
# lot happened Feels quiet Beth aunts charlie working lots helen mo : Ham
# Ì wait 4 bus stop aft ur lect lar dun c Ì go get car come back n pick Ì : Ham
# Aight thanks comin : Ham

# %%
# Out:
# Ham
